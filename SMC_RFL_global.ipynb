# %% [markdown]
# # Restricted Facility Location
#
# ### `SMC` approach

# %%
# import libraries
from scipy.special import softmax

## basic imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')
from IPython.display import clear_output
import seaborn as sns
import cvxpy as cp
import time
clear_output()
myseed = '2404' 
np.random.seed(int(myseed))

# %%
## problem dimensions

B = int(10) 
LAMBDA_extra = 10


TITLE = 'at.csv' 

R = 2e-1
REL_PARAM = 1e-12

# %% [markdown]
# ### utils

# %%
def proj_simplex_vec(V, z=1):
    n_features = V.shape[1]
    U = np.sort(V, axis=1)[:, ::-1]
    z = np.ones(len(V)) * z
    cssv = np.cumsum(U, axis=1) - z[:, np.newaxis]
    ind = np.arange(n_features) + 1
    cond = U - cssv / ind > 0
    rho = np.count_nonzero(cond, axis=1)
    theta = cssv[np.arange(len(V)), rho - 1] / rho
    return np.maximum(V - theta[:, np.newaxis], 0)

# from https://github.com/cvxgrp/dccp/blob/master/dccp/linearize.py

def linearize(expr):
    """Returns the tangent approximation to the expression.

    Gives an elementwise lower (upper) bound for convex (concave)
    expressions. No guarantees for non-DCP expressions.

    Args:
        expr: An expression.

    Returns:
        An affine expression.
    """
    if expr.is_affine():
        return expr
    else:
        if expr.value is None:
            raise ValueError(
                "Cannot linearize non-affine expression with missing variable values."
            )
        tangent = np.real(expr.value) #+ np.imag(expr.value)
        grad_map = expr.grad
        for var in expr.variables():
            if grad_map[var] is None:
                return None
            complex_flag = False
            if var.is_complex() or np.any(np.iscomplex(grad_map[var])):
                complex_flag = True
            if var.ndim > 1:
                temp = cp.reshape(
                    cp.vec(var - var.value), (var.shape[0] * var.shape[1], 1)
                )
                if complex_flag:
                    flattened = np.transpose(np.real(grad_map[var])) @ cp.real(temp) + \
                    np.transpose(np.imag(grad_map[var])) @ cp.imag(temp)
                else:
                    flattened = np.transpose(np.real(grad_map[var])) @ temp
                tangent = tangent + cp.reshape(flattened, expr.shape)
            elif var.size > 1:
                if complex_flag:
                    tangent = tangent + np.transpose(np.real(grad_map[var])) @ (cp.real(var) - np.real(var.value)) \
                    + np.transpose(np.imag(grad_map[var])) @ (cp.imag(var) - np.imag(var.value))
                else:
                    tangent = tangent + np.transpose(np.real(grad_map[var])) @ (var - var.value)
            else:
                if complex_flag:
                    tangent = tangent + np.real(grad_map[var]) * (cp.real(var) - np.real(var.value)) \
                    + np.imag(grad_map[var]) * (cp.imag(var) - np.imag(var.value))
                else:
                    tangent = tangent + np.real(grad_map[var]) * (var - var.value) 
        return tangent

# %% [markdown]
# ### true data generation

# %%
def preprocess(fname,col_locations,col_weight='population',col_city='city'):
    
    ## loading part 
    try:
        
        raw_df = pd.read_csv(fname)
        raw_df.dropna(inplace=True,axis=1)
        N = raw_df.shape[0]

        if isinstance(col_weight,str):
            weights = raw_df[col_weight].values
        elif isinstance(col_weight,numbers.Number):
            weights = raw_df.iloc[:,int(col_weight)].values
        else:
            print('col_weight should either be a column name (str) or location (int)')
            weights = np.ones(N)
            
        weights = np.maximum(weights,0.0)
        if sum(weights)>0:
            weights /= np.sum(weights)
            
        if isinstance(col_city,str):
            city_names = raw_df[col_city].values
        elif isinstance(col_city,numbers.Number):
            city_names = raw_df.iloc[:,int(col_city)].values
        else:
            print('col_city should either be a column name (str) or location (int)')
            city_names = ['city #'+str(elem+1) for elem in range(N)]
            
        assert isinstance(col_locations,list),'col_locations must be a list of names (str) or indices (int)'
        locations = np.zeros((N,len(col_locations)))
        for id_loc,col_loc in enumerate(col_locations):
            if isinstance(col_loc,str):
                buf = raw_df[col_loc].values
            elif isinstance(col_loc,numbers.Number):
                buf = raw_df.iloc[:,int(col_loc)].values
            else:
                print('erroneous prescribed marker for city location... 0 value set for the linked dim.')
                buf = np.zeros(N)
            locations[:,id_loc] = buf.copy()

    except:
        print('-> error while loading your file')
        return None,None,None
    
    return weights,locations,list(city_names)

# %%
weights,locations,city_names = preprocess(TITLE,col_locations=['lat','lng'],col_weight='population',col_city='city')

# %%
N_train = min(len(locations),int(750))
id_train = np.random.choice(np.arange(len(locations)),replace=False,size=N_train)

omegas_train = locations[id_train]
weights_train = weights[id_train]
w_ext = omegas_train.shape[1]

# %% [markdown]
# ### TRAINING
#
# `parametric LP`

# %%
# symmetry breakers tolerances
margin = .0
mu_DCA = 1e-8

# variables
radius = cp.Variable(1)
centrum = cp.Variable(w_ext)
mat_cvx = cp.Variable((B,w_ext))

# parameters
param = cp.Parameter((N_train,B),nonneg=True)

# basic feasible set 
LBS,UBS = np.min(omegas_train,0),np.max(omegas_train,0)
LBS *= (1-np.sign(LBS)*.02)
UBS *= (1+np.sign(UBS)*.02)
r_ref = abs(1/4*np.mean(UBS-LBS))
X = [mat_cvx[e]<=UBS for e in range(B)]+[mat_cvx[e]>=LBS for e in range(B)] 

# prior-knowledge encoding
symmetry_breaks = []
if B>1:
    for e in range(B-1):
        symmetry_breaks += [cp.sum(mat_cvx[e])+margin<=cp.sum(mat_cvx[e+1])]
        
h_bar_smc = LAMBDA_extra*cp.maximum(0,radius[0]-r_ref) if LAMBDA_extra>0 else 0.0
F_param_smc = h_bar_smc 
f1_dc = h_bar_smc+mu_DCA/2*(cp.sum_squares(mat_cvx)+cp.sum_squares(centrum)+cp.sum_squares(radius))

# objective function implementation + centrum "close enough" constraint
for e in range(B):
    X += [cp.norm(mat_cvx[e]-centrum,'inf')<=radius[0]]
    f1_dc += weights_train@cp.multiply(np.ones(N_train),cp.sum(cp.abs(np.ones((N_train,1))@cp.reshape(mat_cvx[e],(1,w_ext))-omegas_train),1))
    F_param_smc += weights_train@cp.multiply(param[:,e].T,cp.sum(cp.abs(np.ones((N_train,1))@cp.reshape(mat_cvx[e],(1,w_ext))-omegas_train),1))

prob_param_smc = cp.Problem(cp.Minimize(F_param_smc),X+symmetry_breaks)

# %%
'''-> h components evaluation <-'''
def heval(mat_val,data=omegas_train,weights=weights_train):
    buf = np.zeros((len(data),B))
    for e in range(B):
        buf[:,e] = np.sum(np.abs(np.outer(np.ones(N_train),mat_val[e])-data),1)
    return np.outer(weights,np.ones(B))*buf

'''-> ERM evaluation<-'''
def Feval(radius,center,mat_val,data=omegas_train,weights=weights_train):
    values = heval(mat_val,data,weights)
    return LAMBDA_extra*max(0,radius[0]-r_ref) + np.sum(np.min(values,1))

''' -> active components <- '''
def rho_active_sets(vals,rho=1e-10):
    indices = []
    minvals,maxvals = np.min(vals,1),np.max(vals,1)
    shifted_vals = (np.outer(maxvals,np.ones(vals.shape[1]))-np.array(vals))/(np.outer(maxvals,np.ones(vals.shape[1]))-np.outer(minvals,np.ones(vals.shape[1])))
    for idrow,row in enumerate(shifted_vals):
        tokeep = len(np.where(row>=1-rho)[0])
        indices.append(list(np.argsort(vals[idrow]))[:tokeep])
    return indices

# %%
'''-> computation of parameters <-
weights ndarray of shape (N_train,BB)
'''
def w2p(weights):
    param.value = weights
    
'''-> computation of f2_dc <-
weights ndarray of shape (N_train,BB) (opt)
'''
def w2l(weights):
    expr = 0.0
    loc_param = 1-weights
    for e in range(B):
        expr += weights_train@cp.multiply(loc_param[:,e].T,cp.sum(cp.abs(np.ones((N_train,1))@cp.reshape(mat_cvx[e],(1,w_ext))-omegas_train),1))
    return linearize(expr+mu_DCA/2*(cp.sum_squares(mat_cvx)+cp.sum_squares(centrum)+cp.sum_squares(radius)))
    
    
''' weights computations '''

def Q_opt(vals):
    buf = np.zeros(vals.shape)
    for s,sigma_s in enumerate(np.argmin(vals,1)):
        buf[s,sigma_s] += 1
    return buf

def Q_safe(vals,Q_current,Q_hat,Q_star,C):
    Q_next = np.zeros(Q_star.shape)
    combinations = np.zeros(len(Q_current))
    for _,Q_hat_elem in enumerate(Q_hat):
        num = np.sum((Q_current[_]-Q_star[_])*vals[_])
        denum = np.sum((Q_hat_elem-Q_star[_])*vals[_])
        if C*num>=denum:
            combinations[_] = 1
        else:
            combinations[_] = min(1,max(0,C*(num/max(1e-9,denum))))
        Q_next[_] = combinations[_]*Q_hat_elem+(1-combinations[_])*Q_star[_]
    return Q_next,combinations

def Q_hat_bb(vals,Q,param=1):
    minids = np.argmin(vals,1)
    Q_hat = Q.copy()
    for s,sigma_s in enumerate(minids):
        Q_hat[s] -= param*np.ones(vals.shape[1])
        Q_hat[s,sigma_s] += 2*param
    return proj_simplex_vec(Q_hat)

def Q_hat_mm(vals,param=1):
    minvals,maxvals = np.min(vals,1),np.max(vals,1)
    return proj_simplex_vec(param*(np.outer(maxvals,np.ones(vals.shape[1]))-np.array(vals))/(np.outer(maxvals,np.ones(vals.shape[1]))-np.outer(minvals,np.ones(vals.shape[1]))))

def Q_hat_softmin(vals,param=1,num_pert_inf=5e-7):
    pert_vals = vals+np.random.uniform(-num_pert_inf,num_pert_inf,vals.shape)
    return softmax(-param*pert_vals/np.maximum(1e-4,np.abs(np.outer(np.mean(vals,1),np.ones(B)))),axis=1)

# %% [markdown]
# For any $(l,l_+) \in [n_s]^2$,
#
# $$M^{(s)}_{l_+,l} = \max_{u \,\in\, \mathcal{S}}\, h^{(s)}_{l_+}(u)-h^{(s)}_{l}(u) \quad \text{s.t.} \quad h^{(s)}_{l}(u)\leq h^{(s)}(u)$$
#
#
# <b>FL</b>
#
# * ...
#
# <i>NOTE</i>:
#
# * if there exists $l_+ \in [n_s]$ such that $\hat{M}^{(s)}_{l_+,l}<0$ then $l$ is <b>not</b> active at any minimizer of $F$ over $\mathcal{S}$ and one sets $M^{(s)}_{l_+,l}=0$
# * else, one sets $M^{(s)}_{l_+,l}=\hat{M}^{(s)}_{l_+,l}$

# %%
def bigM_FL(OMEGAS,weights=weights_train,Bparam=B,R_inf=R,c_centers=None):
    
    print('-> computation with R_inf = '+str(R_inf)+' ; p-norm with p = '+str(np.inf))
    print(' ')
    
    # init 
    N_loc = len(OMEGAS)
    data_loc = OMEGAS.copy()
    if c_centers is None:
        c_centers = np.zeros((Bparam,data_loc.shape[1]))
    M_list = [np.zeros((Bparam,Bparam)) for _ in range(N_loc)]

    # main loop
    for s,omega in enumerate(data_loc):
        for l_plus in range(Bparam):
            x_l_plus = c_centers[l_plus]
            x_l_plus_up = x_l_plus - R_inf*np.sign(omega-x_l_plus)
            up = np.sum(np.abs(omega-x_l_plus_up))
            for l in range(Bparam):
                if l==l_plus:
                    pass
                else:
                    x_l = c_centers[l]
                    x_l_down = x_l + np.minimum(R_inf,np.abs(omega-x_l))*np.sign(omega-x_l)
                    down = np.sum(np.abs(omega-x_l_down))
                    # computations
                    M_list[s][l_plus,l] = weights[s]*(up-down)
        if (s+1)%(np.ceil(N_loc/10))==0:
            print('ok for '+str((s+1)/N_loc*100)+'%')
    return M_list

# %%
NREPS = int(5)
Q_init_mats = []
for rep in range(NREPS):
    Q_init = np.random.uniform(0,1,(N_train,B))
    Q_init = np.array([q/np.sum(q) for q in Q_init])
    Q_init_mats.append(Q_init)

N_outer_max = int(10)
N_max = int(400)
tol_loc,tol_glob = 1e-8,5e-7

import gurobipy

local_env = gurobipy.Env()
local_env.setParam('TimeLimit', 180) # in seconds
local_env.setParam('Heuristics',.25) # in %
# Out:
# Academic license - for non-commercial use only - expires 2024-09-05
# Using license file /Users/guiom_vds/gurobi.lic
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Changed value of parameter Heuristics to 0.25
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05

# %%
def RRAM(mode='am'):

    ## init
    fval = []
    t = []
    repIDs = []
    locopt = []
    endval_single_run = []
    endval = [] 

    if mode=='maxmin':
        param_schedule = lambda k: k**(2/3) 
        C_schedule = lambda k: 2/(k**(1/2)+3)
    elif mode=='softmin':
        param_schedule = lambda k: (3/2)**(k**(3/4)) if (3/2)**(k**(3/4))<1e16 else np.inf
        C_schedule = lambda k: 2/(k**(1/2)+3)
    elif mode=='baratt-boyd':
        param_schedule = lambda k: 1e-1
        C_schedule = lambda k: 1
    else: # am
        param_schedule = lambda k: 1
        C_schedule = lambda k: 0 

    print('=> '+str(mode)+' (START)')
    print(' ')

    for rep in range(NREPS):
        print('new rep #'+str(rep+1))
        print(' ')

        t_init = time.time()
        f_overallbest = np.inf
        mat_out = None
        rad_out = None
        center_out = None
        LO = False

        for k_outer in range(N_outer_max):

            print('OUTER #'+str(k_outer+1))
            print(' ')

            if k_outer==0:
                Q = Q_init_mats[rep].copy()
                w2p(Q)
                ref_val = np.inf
            else:
                components_ = heval(mat_cvx.value)
                Q = Q_opt(components_)
                w2p(Q)
                ref_val = Feval(radius.value,centrum.value,mat_cvx.value)
                print('restart w/ F = '+str(ref_val))
                print(' ')

            ### LOCAL

            try:

                print('local')
                print(' ')

                ## main loop
                for k in range(N_max):

                    C,kappa = C_schedule(k),param_schedule(k)

                    #### set x 
                    prob_param_smc.solve(solver=cp.MOSEK,warm_start=True)

                    #### set weights
                    components_ = heval(mat_cvx.value)
                    prev = np.sum(components_/N_train*Q)
                    if mode=='maxmin':
                        Q_hat = Q_hat_mm(components_,param=kappa)
                        Q_star = Q_opt(components_)
                        Q,combis = Q_safe(components_,Q,Q_hat,Q_star,C)
                    elif mode=='softmin':
                        Q_hat = Q_hat_softmin(components_,param=kappa)
                        Q_star = Q_opt(components_)
                        Q,combis = Q_safe(components_,Q,Q_hat,Q_star,C)
                    elif mode=='baratt-boyd':
                        Q,combis = Q_hat_bb(components_,Q,param=kappa),np.array([C])
                    else:
                        Q,combis = Q_opt(components_),np.array([C])
                    w2p(Q)
                    post = np.sum(components_/N_train*Q)
                    F_Q_plus_x_plus = F_param_smc.value
                    G_crit = max(0,prev-post)
                    F_ = Feval(radius.value,centrum.value,mat_cvx.value)
                    print("iter. %04d | Fval. %4.4e | BICval. %4.4e | Gcrit_x. %4.4e | avg. eps. %4.4e " % (k + 1, F_,F_Q_plus_x_plus,G_crit,np.mean(combis)))
                    if (ref_val-F_)<tol_loc and k>10:
                        print('=> convergence to criticality ... polishing phase')
                        Q_final = Q_opt(heval(mat_cvx.value))
                        w2p(Q_final)
                        prob_param_smc.solve(solver=cp.MOSEK,warm_start=True)
                        F_ = Feval(radius.value,centrum.value,mat_cvx.value)
                        print('final::: Fval. %4.4e | BICval. %4.4e' % (F_,prob_param_smc.value))
                        break;
                    else:
                        ref_val = F_Q_plus_x_plus
                if k==N_max-1:
                    F_ = Feval(radius.value,centrum.value,mat_cvx.value)
            except: 
                print('... solver failed | early interruption ')
                F_ = Feval(radius.value,centrum.value,mat_cvx.value)
            print(' ')
            if F_<=f_overallbest:
                print(' /!\ NEW BEST | F = '+str(F_)+'  /!\ ')
                f_overallbest = F_
                mat_out = mat_cvx.value
                center_out = centrum.value
                rad_out = radius.value
                print(' ')
            if k_outer==0:
                endval_single_run.append(F_)
            t.append(time.time()-t_init)
            fval.append(F_)
            repIDs.append(rep)

            ### GLOBAL
            # @check in order not to cycle...
            vals = heval(mat_out)
            active_indices = rho_active_sets(vals,rho=REL_PARAM)
            print('global')
            print(' ')
            try:
                list_cstr_glob_cvx = []
                list_cstr_glob_cvx += [cp.norm(mat_cvx[e]-mat_out[e],'inf')<=R for e in range(B)]
                list_cstr_glob_cvx += [cp.norm(mat_cvx[e]-mat_out[e],'inf')<=R,cp.abs(radius[0]-rad_out[0])<=R]
                ML_loc = bigM_FL(omegas_train,c_centers=mat_cvx.value)
                fun_obj_glob_cvx = h_bar_smc
                t_var = {} 
                for s,omega_s in enumerate(omegas_train):
                    active_indices_s = active_indices[s]
                    l_elected = active_indices_s[0]
                    n_a_s = len(active_indices_s)
                    if n_a_s>1:
                        t_var['t_'+str(s)] = cp.Variable(n_a_s,boolean=True)
                        alpha_s = cp.Variable(1,name='alpha_'+str(s))
                        list_cstr_glob_cvx += [cp.sum(t_var['t_'+str(s)])==1]
                        init_t = np.zeros(n_a_s)
                        init_t[0] += 1
                        t_var['t_'+str(s)].value = init_t
                        fun_obj_glob_cvx += alpha_s[0]
                        alpha_s.value = np.array([weights_train[s]*np.sum(np.abs(omega_s-mat_cvx.value[l_elected]))])
                        for l_plus in active_indices_s:
                            M_bounds = ML_loc[s][l_plus]
                            list_cstr_glob_cvx += [weights_train[s]*cp.norm(omega_s-mat_cvx[l_plus],1)<=alpha_s+cp.sum(cp.multiply(t_var['t_'+str(s)],M_bounds[active_indices_s]))]
                    else:
                        fun_obj_glob_cvx += weights_train[s]*cp.norm(omega_s-mat_cvx[l_elected],1)
                prob_glob_cvx = cp.Problem(cp.Minimize(fun_obj_glob_cvx),list_cstr_glob_cvx+X+symmetry_breaks)
                #local_env.setParam('BestObjStop',f_overallbest*(1-.2*np.sign(f_overallbest)))
                prob_glob_cvx.solve(solver=cp.GUROBI,verbose=True,warm_start=True,env=local_env)
                F_ =  Feval(radius.value,centrum.value,mat_cvx.value)
            except:
                print(' ')
                print('GUROBI failure or manual STOP...')
                F_ = np.inf

            if F_ <= f_overallbest-tol_glob:
                print(' ')
                print(' /!\ NEW BEST | F = '+str(F_)+'  /!\ ')
                print(' ')
                f_overallbest = F_
                t.append(time.time()-t_init)
                fval.append(F_)
                repIDs.append(rep)
            else:
                print(' ')
                print('no improvement after globalization technique... ')
                LO = prob_glob_cvx.status=='optimal'
                break;
        print(' ')
        print('=> '+str(mode)+' (END)')
        print(' ')
        locopt.append(LO)
        endval.append(f_overallbest)
        
    return t,fval,repIDs,locopt,endval,endval_single_run

# %%
t_sm,fval_sm,repIDs_sm,locopt_sm,endval_sm,endval_single_run_sm = RRAM(mode='softmin')
# Out:
# => softmin (START)
#
# new rep #1
#
# OUTER #1
#
# local
#
# iter. 0001 | Fval. 1.7752e+00 | BICval. 1.8040e+00 | Gcrit_x. 7.9839e-05 | avg. eps. 6.7526e-01
# iter. 0002 | Fval. 9.9519e-01 | BICval. 1.2972e+00 | Gcrit_x. 1.7410e-03 | avg. eps. 5.3202e-01
# iter. 0003 | Fval. 9.5344e-01 | BICval. 1.0854e+00 | Gcrit_x. 8.7083e-04 | avg. eps. 3.1872e-01
# iter. 0004 | Fval. 7.7465e-01 | BICval. 8.6967e-01 | Gcrit_x. 7.7005e-04 | avg. eps. 3.5466e-01
# iter. 0005 | Fval. 7.7777e-01 | BICval. 8.1419e-01 | Gcrit_x. 2.9852e-04 | avg. eps. 1.6109e-01
# iter. 0006 | Fval. 7.7090e-01 | BICval. 7.8608e-01 | Gcrit_x. 1.3421e-04 | avg. eps. 8.5735e-02
# iter. 0007 | Fval. 7.6527e-01 | BICval. 7.7212e-01 | Gcrit_x. 6.4499e-05 | avg. eps. 6.0851e-02
# iter. 0008 | Fval. 7.5191e-01 | BICval. 7.5681e-01 | Gcrit_x. 5.2195e-05 | avg. eps. 7.3158e-02
# iter. 0009 | Fval. 7.3721e-01 | BICval. 7.4233e-01 | Gcrit_x. 5.4202e-05 | avg. eps. 8.0919e-02
# iter. 0010 | Fval. 6.7724e-01 | BICval. 6.8588e-01 | Gcrit_x. 2.4025e-04 | avg. eps. 2.5843e-01
# iter. 0011 | Fval. 6.2011e-01 | BICval. 6.2412e-01 | Gcrit_x. 9.8134e-05 | avg. eps. 3.0301e-01
# iter. 0012 | Fval. 6.1645e-01 | BICval. 6.1847e-01 | Gcrit_x. 2.4170e-05 | avg. eps. 2.2636e-01
# iter. 0013 | Fval. 6.0398e-01 | BICval. 6.0502e-01 | Gcrit_x. 2.8436e-05 | avg. eps. 2.1749e-01
# iter. 0014 | Fval. 6.0359e-01 | BICval. 6.0392e-01 | Gcrit_x. 4.2119e-06 | avg. eps. 1.7191e-01
# iter. 0015 | Fval. 6.0354e-01 | BICval. 6.0364e-01 | Gcrit_x. 1.3614e-06 | avg. eps. 1.5511e-01
# iter. 0016 | Fval. 6.0354e-01 | BICval. 6.0357e-01 | Gcrit_x. 4.0424e-07 | avg. eps. 1.5048e-01
# iter. 0017 | Fval. 6.0349e-01 | BICval. 6.0352e-01 | Gcrit_x. 2.8339e-07 | avg. eps. 1.5521e-01
# iter. 0018 | Fval. 6.0349e-01 | BICval. 6.0350e-01 | Gcrit_x. 8.1277e-08 | avg. eps. 1.5680e-01
# iter. 0019 | Fval. 6.0349e-01 | BICval. 6.0350e-01 | Gcrit_x. 2.2946e-08 | avg. eps. 1.5576e-01
# iter. 0020 | Fval. 6.0349e-01 | BICval. 6.0350e-01 | Gcrit_x. 6.3345e-09 | avg. eps. 1.5454e-01
# iter. 0021 | Fval. 6.0349e-01 | BICval. 6.0350e-01 | Gcrit_x. 1.7220e-09 | avg. eps. 1.5334e-01
# iter. 0022 | Fval. 6.0349e-01 | BICval. 6.0349e-01 | Gcrit_x. 4.6345e-10 | avg. eps. 1.5253e-01
# iter. 0023 | Fval. 6.0349e-01 | BICval. 6.0349e-01 | Gcrit_x. 1.2205e-10 | avg. eps. 1.4890e-01
# iter. 0024 | Fval. 6.0349e-01 | BICval. 6.0349e-01 | Gcrit_x. 3.1193e-11 | avg. eps. 1.4806e-01
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0349e-01 | BICval. 6.0349e-01
#
#  /!\ NEW BEST | F = 0.6034949248454681  /!\
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:29 PM: Your problem has 41 variables, 69 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:29 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:29 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:29 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:29 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:29 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:29 PM: Finished problem compilation (took 4.500e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:29 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 933 rows, 442 columns and 1895 nonzeros
# Model fingerprint: 0xba982b66
# Variable types: 430 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+01]
#
# User MIP start produced solution with objective 0.603495 (0.01s)
# Loaded user MIP start with objective 0.603495
#
# Presolve removed 716 rows and 321 columns
# Presolve time: 0.00s
# Presolved: 217 rows, 121 columns, 468 nonzeros
# Variable types: 115 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 6.008849e-01, 113 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60088    0    6    0.60349    0.60088  0.43%     -    0s
# H    0     0                       0.6034729    0.60234  0.19%     -    0s
#      0     0    0.60345    0    6    0.60347    0.60345  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#
# Explored 1 nodes (127 simplex iterations) in 0.03 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.603473 0.603495
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.034729434696e-01, best bound 6.034535964978e-01, gap 0.0032%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:29 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:29 PM: Optimal value: 6.035e-01
# (CVXPY) Jul 25 02:56:29 PM: Compilation took 4.500e-01 seconds
# (CVXPY) Jul 25 02:56:29 PM: Solver (including time spent in interface) took 8.411e-02 seconds
#
#  /!\ NEW BEST | F = 0.603461648769809  /!\
#
# OUTER #2
#
# restart w/ F = 0.603461648769809
#
# local
#
# iter. 0001 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 4.3368e-19 | avg. eps. 7.0086e-16
# iter. 0002 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 5.5445e-16
# iter. 0003 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 3.5835e-16
# iter. 0004 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 2.0609e-16
# iter. 0005 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 1.0696e-16
# iter. 0006 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 5.0258e-17
# iter. 0007 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 2.2281e-17
# iter. 0008 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 9.3104e-18
# iter. 0009 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 3.3767e-18
# iter. 0010 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 1.3213e-18
# iter. 0011 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 2.7102e-19
# iter. 0012 | Fval. 6.0346e-01 | BICval. 6.0346e-01 | Gcrit_x. 0.0000e+00 | avg. eps. 3.1012e-19
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0346e-01 | BICval. 6.0346e-01
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:30 PM: Your problem has 41 variables, 69 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:30 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:30 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:30 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:30 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:30 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:30 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:30 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:30 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:31 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:31 PM: Finished problem compilation (took 4.479e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:31 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 933 rows, 442 columns and 1895 nonzeros
# Model fingerprint: 0x8be68c00
# Variable types: 430 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+01]
#
# User MIP start produced solution with objective 0.603535 (0.01s)
# Loaded user MIP start with objective 0.603535
#
# Presolve removed 716 rows and 321 columns
# Presolve time: 0.01s
# Presolved: 217 rows, 121 columns, 468 nonzeros
# Found heuristic solution: objective 0.6034729
# Variable types: 115 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 6.010352e-01, 116 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60104    0    6    0.60347    0.60104  0.40%     -    0s
#      0     0    0.60318    0    1    0.60347    0.60318  0.05%     -    0s
#      0     0     cutoff    0         0.60347    0.60347  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#
# Explored 1 nodes (130 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.603473 0.603535
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.034729434696e-01, best bound 6.034729434696e-01, gap 0.0000%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:31 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:31 PM: Optimal value: 6.035e-01
# (CVXPY) Jul 25 02:56:31 PM: Compilation took 4.479e-01 seconds
# (CVXPY) Jul 25 02:56:31 PM: Solver (including time spent in interface) took 1.089e-01 seconds
#
# no improvement after globalization technique...
#
# => softmin (END)
#
# new rep #2
#
# OUTER #1
#
# local
#
# iter. 0001 | Fval. 1.7519e+00 | BICval. 1.7961e+00 | Gcrit_x. 1.2279e-04 | avg. eps. 6.8852e-01
# iter. 0002 | Fval. 9.7939e-01 | BICval. 1.2716e+00 | Gcrit_x. 1.6854e-03 | avg. eps. 5.5623e-01
# iter. 0003 | Fval. 7.8400e-01 | BICval. 9.5083e-01 | Gcrit_x. 1.2747e-03 | avg. eps. 4.3716e-01
# iter. 0004 | Fval. 7.7229e-01 | BICval. 8.4499e-01 | Gcrit_x. 5.4269e-04 | avg. eps. 2.4188e-01
# iter. 0005 | Fval. 7.5165e-01 | BICval. 7.8414e-01 | Gcrit_x. 3.0635e-04 | avg. eps. 2.8554e-01
# iter. 0006 | Fval. 6.4274e-01 | BICval. 6.6566e-01 | Gcrit_x. 3.1633e-04 | avg. eps. 3.6854e-01
# iter. 0007 | Fval. 6.4175e-01 | BICval. 6.5025e-01 | Gcrit_x. 8.0228e-05 | avg. eps. 3.1494e-01
# iter. 0008 | Fval. 6.4175e-01 | BICval. 6.4476e-01 | Gcrit_x. 3.0016e-05 | avg. eps. 2.8688e-01
# iter. 0009 | Fval. 6.4175e-01 | BICval. 6.4278e-01 | Gcrit_x. 1.0810e-05 | avg. eps. 2.7411e-01
# iter. 0010 | Fval. 6.4175e-01 | BICval. 6.4209e-01 | Gcrit_x. 3.7633e-06 | avg. eps. 2.7144e-01
# iter. 0011 | Fval. 6.4175e-01 | BICval. 6.4186e-01 | Gcrit_x. 1.2717e-06 | avg. eps. 2.7984e-01
# iter. 0012 | Fval. 6.4175e-01 | BICval. 6.4178e-01 | Gcrit_x. 4.1818e-07 | avg. eps. 3.0608e-01
# iter. 0013 | Fval. 6.4175e-01 | BICval. 6.4176e-01 | Gcrit_x. 1.3764e-07 | avg. eps. 3.5486e-01
# iter. 0014 | Fval. 6.4175e-01 | BICval. 6.4175e-01 | Gcrit_x. 4.0186e-08 | avg. eps. 3.9328e-01
# iter. 0015 | Fval. 6.2363e-01 | BICval. 6.2484e-01 | Gcrit_x. 5.7960e-05 | avg. eps. 4.1673e-01
# iter. 0016 | Fval. 6.0911e-01 | BICval. 6.0964e-01 | Gcrit_x. 2.9289e-05 | avg. eps. 2.6941e-01
# iter. 0017 | Fval. 6.0739e-01 | BICval. 6.0794e-01 | Gcrit_x. 7.8907e-06 | avg. eps. 2.1846e-01
# iter. 0018 | Fval. 6.0538e-01 | BICval. 6.0559e-01 | Gcrit_x. 6.3124e-06 | avg. eps. 2.2136e-01
# iter. 0019 | Fval. 6.0524e-01 | BICval. 6.0531e-01 | Gcrit_x. 9.4892e-07 | avg. eps. 1.7377e-01
# iter. 0020 | Fval. 6.0522e-01 | BICval. 6.0524e-01 | Gcrit_x. 3.1566e-07 | avg. eps. 1.3414e-01
# iter. 0021 | Fval. 6.0522e-01 | BICval. 6.0523e-01 | Gcrit_x. 7.7766e-08 | avg. eps. 1.2223e-01
# iter. 0022 | Fval. 6.0522e-01 | BICval. 6.0523e-01 | Gcrit_x. 2.0940e-08 | avg. eps. 1.1823e-01
# iter. 0023 | Fval. 6.0522e-01 | BICval. 6.0522e-01 | Gcrit_x. 5.5382e-09 | avg. eps. 1.1914e-01
# iter. 0024 | Fval. 6.0522e-01 | BICval. 6.0522e-01 | Gcrit_x. 1.4424e-09 | avg. eps. 1.2022e-01
# iter. 0025 | Fval. 6.0522e-01 | BICval. 6.0522e-01 | Gcrit_x. 3.6897e-10 | avg. eps. 1.1993e-01
# iter. 0026 | Fval. 6.0522e-01 | BICval. 6.0522e-01 | Gcrit_x. 9.2131e-11 | avg. eps. 1.1658e-01
# iter. 0027 | Fval. 6.0522e-01 | BICval. 6.0522e-01 | Gcrit_x. 2.1834e-11 | avg. eps. 1.1513e-01
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0522e-01 | BICval. 6.0522e-01
#
#  /!\ NEW BEST | F = 0.605223656231173  /!\
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:33 PM: Your problem has 23 variables, 51 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:33 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:33 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:33 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:33 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:33 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:33 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:33 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:33 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:34 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:34 PM: Finished problem compilation (took 4.214e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:34 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 891 rows, 412 columns and 1787 nonzeros
# Model fingerprint: 0x0e60a2a4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 5e+01]
# Presolve removed 655 rows and 179 columns
# Presolve time: 0.01s
# Presolved: 236 rows, 233 columns, 505 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0      handle free variables                          0s
#       97    6.0522366e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 97 iterations and 0.01 seconds
# Optimal objective  6.052236562e-01
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:34 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:34 PM: Optimal value: 6.052e-01
# (CVXPY) Jul 25 02:56:34 PM: Compilation took 4.214e-01 seconds
# (CVXPY) Jul 25 02:56:34 PM: Solver (including time spent in interface) took 5.562e-02 seconds
#
# no improvement after globalization technique...
#
# => softmin (END)
#
# new rep #3
#
# OUTER #1
#
# local
#
# iter. 0001 | Fval. 1.3872e+00 | BICval. 1.6304e+00 | Gcrit_x. 9.1761e-04 | avg. eps. 7.6842e-01
# iter. 0002 | Fval. 8.0348e-01 | BICval. 1.1145e+00 | Gcrit_x. 1.7363e-03 | avg. eps. 5.6140e-01
# iter. 0003 | Fval. 7.5618e-01 | BICval. 9.0976e-01 | Gcrit_x. 1.0194e-03 | avg. eps. 3.9351e-01
# iter. 0004 | Fval. 6.4222e-01 | BICval. 7.2579e-01 | Gcrit_x. 7.8301e-04 | avg. eps. 3.9967e-01
# iter. 0005 | Fval. 6.4175e-01 | BICval. 6.7516e-01 | Gcrit_x. 2.7499e-04 | avg. eps. 3.1416e-01
# iter. 0006 | Fval. 6.4175e-01 | BICval. 6.5449e-01 | Gcrit_x. 1.1296e-04 | avg. eps. 2.7085e-01
# iter. 0007 | Fval. 6.4175e-01 | BICval. 6.4642e-01 | Gcrit_x. 4.4095e-05 | avg. eps. 2.5020e-01
# iter. 0008 | Fval. 6.4175e-01 | BICval. 6.4340e-01 | Gcrit_x. 1.6487e-05 | avg. eps. 2.4128e-01
# iter. 0009 | Fval. 6.4175e-01 | BICval. 6.4231e-01 | Gcrit_x. 5.9350e-06 | avg. eps. 2.3917e-01
# iter. 0010 | Fval. 6.4175e-01 | BICval. 6.4193e-01 | Gcrit_x. 2.0654e-06 | avg. eps. 2.4164e-01
# iter. 0011 | Fval. 6.4175e-01 | BICval. 6.4181e-01 | Gcrit_x. 6.9713e-07 | avg. eps. 2.4858e-01
# iter. 0012 | Fval. 6.4175e-01 | BICval. 6.4176e-01 | Gcrit_x. 2.2879e-07 | avg. eps. 2.6560e-01
# iter. 0013 | Fval. 6.4175e-01 | BICval. 6.4175e-01 | Gcrit_x. 7.4092e-08 | avg. eps. 3.0680e-01
# iter. 0014 | Fval. 6.1538e-01 | BICval. 6.1681e-01 | Gcrit_x. 6.6186e-05 | avg. eps. 2.7781e-01
# iter. 0015 | Fval. 6.1360e-01 | BICval. 6.1430e-01 | Gcrit_x. 1.0017e-05 | avg. eps. 2.5296e-01
# iter. 0016 | Fval. 6.1129e-01 | BICval. 6.1185e-01 | Gcrit_x. 8.5958e-06 | avg. eps. 2.6477e-01
# iter. 0017 | Fval. 6.0867e-01 | BICval. 6.0925e-01 | Gcrit_x. 9.1745e-06 | avg. eps. 2.5272e-01
# iter. 0018 | Fval. 6.0859e-01 | BICval. 6.0876e-01 | Gcrit_x. 2.3961e-06 | avg. eps. 1.7900e-01
# iter. 0019 | Fval. 6.0836e-01 | BICval. 6.0845e-01 | Gcrit_x. 1.3360e-06 | avg. eps. 1.6562e-01
# iter. 0020 | Fval. 6.0832e-01 | BICval. 6.0835e-01 | Gcrit_x. 4.2044e-07 | avg. eps. 1.5174e-01
# iter. 0021 | Fval. 6.0821e-01 | BICval. 6.0823e-01 | Gcrit_x. 3.4638e-07 | avg. eps. 1.5986e-01
# iter. 0022 | Fval. 6.0810e-01 | BICval. 6.0811e-01 | Gcrit_x. 2.7871e-07 | avg. eps. 1.6464e-01
# iter. 0023 | Fval. 6.0810e-01 | BICval. 6.0810e-01 | Gcrit_x. 4.6697e-08 | avg. eps. 1.5223e-01
# iter. 0024 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 3.5966e-08 | avg. eps. 1.4386e-01
# iter. 0025 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 9.2316e-09 | avg. eps. 1.3878e-01
# iter. 0026 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 2.3478e-09 | avg. eps. 1.3666e-01
# iter. 0027 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 5.8941e-10 | avg. eps. 1.3662e-01
# iter. 0028 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 1.4645e-10 | avg. eps. 1.3442e-01
# iter. 0029 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 3.5766e-11 | avg. eps. 1.3377e-01
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0809e-01 | BICval. 6.0809e-01
#
#  /!\ NEW BEST | F = 0.6080879302502961  /!\
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:36 PM: Your problem has 23 variables, 51 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:36 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:36 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:36 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:36 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:36 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:36 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:36 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:36 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:36 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:36 PM: Finished problem compilation (took 3.483e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:36 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 891 rows, 412 columns and 1787 nonzeros
# Model fingerprint: 0x261932e4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 5e+01]
# Presolve removed 650 rows and 176 columns
# Presolve time: 0.01s
# Presolved: 241 rows, 236 columns, 517 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0      handle free variables                          0s
#      113    6.0808793e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 113 iterations and 0.01 seconds
# Optimal objective  6.080879302e-01
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:36 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:36 PM: Optimal value: 6.081e-01
# (CVXPY) Jul 25 02:56:36 PM: Compilation took 3.483e-01 seconds
# (CVXPY) Jul 25 02:56:36 PM: Solver (including time spent in interface) took 5.755e-02 seconds
#
# no improvement after globalization technique...
#
# => softmin (END)
#
# new rep #4
#
# OUTER #1
#
# local
#
# iter. 0001 | Fval. 1.5224e+00 | BICval. 1.6790e+00 | Gcrit_x. 7.5783e-04 | avg. eps. 7.4836e-01
# iter. 0002 | Fval. 8.7145e-01 | BICval. 1.1355e+00 | Gcrit_x. 1.6507e-03 | avg. eps. 5.9683e-01
# iter. 0003 | Fval. 8.2913e-01 | BICval. 9.5900e-01 | Gcrit_x. 8.7319e-04 | avg. eps. 4.8045e-01
# iter. 0004 | Fval. 8.2737e-01 | BICval. 8.8239e-01 | Gcrit_x. 4.1153e-04 | avg. eps. 3.6058e-01
# iter. 0005 | Fval. 7.9242e-01 | BICval. 8.2443e-01 | Gcrit_x. 2.9943e-04 | avg. eps. 2.3548e-01
# iter. 0006 | Fval. 6.4271e-01 | BICval. 6.6556e-01 | Gcrit_x. 5.0372e-04 | avg. eps. 3.4218e-01
# iter. 0007 | Fval. 6.4201e-01 | BICval. 6.5042e-01 | Gcrit_x. 7.9312e-05 | avg. eps. 2.9809e-01
# iter. 0008 | Fval. 6.4201e-01 | BICval. 6.4499e-01 | Gcrit_x. 2.9670e-05 | avg. eps. 2.7802e-01
# iter. 0009 | Fval. 6.4201e-01 | BICval. 6.4304e-01 | Gcrit_x. 1.0685e-05 | avg. eps. 2.7238e-01
# iter. 0010 | Fval. 6.4201e-01 | BICval. 6.4235e-01 | Gcrit_x. 3.7198e-06 | avg. eps. 2.7874e-01
# iter. 0011 | Fval. 6.4201e-01 | BICval. 6.4211e-01 | Gcrit_x. 1.3350e-06 | avg. eps. 2.9609e-01
# iter. 0012 | Fval. 6.4201e-01 | BICval. 6.4204e-01 | Gcrit_x. 3.8624e-07 | avg. eps. 3.1381e-01
# iter. 0013 | Fval. 6.4201e-01 | BICval. 6.4202e-01 | Gcrit_x. 1.0102e-07 | avg. eps. 3.2787e-01
# iter. 0014 | Fval. 6.1565e-01 | BICval. 6.1708e-01 | Gcrit_x. 6.8747e-05 | avg. eps. 2.7621e-01
# iter. 0015 | Fval. 6.1387e-01 | BICval. 6.1457e-01 | Gcrit_x. 1.0027e-05 | avg. eps. 2.5207e-01
# iter. 0016 | Fval. 6.1156e-01 | BICval. 6.1212e-01 | Gcrit_x. 8.6120e-06 | avg. eps. 2.7407e-01
# iter. 0017 | Fval. 6.0894e-01 | BICval. 6.0952e-01 | Gcrit_x. 9.1834e-06 | avg. eps. 2.6303e-01
# iter. 0018 | Fval. 6.0886e-01 | BICval. 6.0903e-01 | Gcrit_x. 2.3883e-06 | avg. eps. 1.9949e-01
# iter. 0019 | Fval. 6.0863e-01 | BICval. 6.0872e-01 | Gcrit_x. 1.3325e-06 | avg. eps. 1.8885e-01
# iter. 0020 | Fval. 6.0859e-01 | BICval. 6.0862e-01 | Gcrit_x. 4.1804e-07 | avg. eps. 1.7432e-01
# iter. 0021 | Fval. 6.0848e-01 | BICval. 6.0850e-01 | Gcrit_x. 3.4511e-07 | avg. eps. 1.8202e-01
# iter. 0022 | Fval. 6.0837e-01 | BICval. 6.0838e-01 | Gcrit_x. 2.7859e-07 | avg. eps. 1.8646e-01
# iter. 0023 | Fval. 6.0837e-01 | BICval. 6.0837e-01 | Gcrit_x. 4.6450e-08 | avg. eps. 1.7477e-01
# iter. 0024 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 3.5859e-08 | avg. eps. 1.6594e-01
# iter. 0025 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 9.2099e-09 | avg. eps. 1.6094e-01
# iter. 0026 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 2.3422e-09 | avg. eps. 1.5867e-01
# iter. 0027 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 5.8817e-10 | avg. eps. 1.5863e-01
# iter. 0028 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 1.4598e-10 | avg. eps. 1.5641e-01
# iter. 0029 | Fval. 6.0836e-01 | BICval. 6.0836e-01 | Gcrit_x. 3.5708e-11 | avg. eps. 1.9939e-01
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0836e-01 | BICval. 6.0836e-01
#
#  /!\ NEW BEST | F = 0.6083575219673514  /!\
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:38 PM: Your problem has 23 variables, 51 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:38 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:38 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:38 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:38 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:38 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:38 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:38 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:38 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:39 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:39 PM: Finished problem compilation (took 4.382e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:39 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 891 rows, 412 columns and 1787 nonzeros
# Model fingerprint: 0x55813720
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 5e+01]
# Presolve removed 649 rows and 175 columns
# Presolve time: 0.01s
# Presolved: 242 rows, 237 columns, 519 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0      handle free variables                          0s
#      116    6.0835752e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 116 iterations and 0.01 seconds
# Optimal objective  6.083575220e-01
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:39 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:39 PM: Optimal value: 6.084e-01
# (CVXPY) Jul 25 02:56:39 PM: Compilation took 4.382e-01 seconds
# (CVXPY) Jul 25 02:56:39 PM: Solver (including time spent in interface) took 5.328e-02 seconds
#
# no improvement after globalization technique...
#
# => softmin (END)
#
# new rep #5
#
# OUTER #1
#
# local
#
# iter. 0001 | Fval. 9.5061e-01 | BICval. 1.4509e+00 | Gcrit_x. 1.7098e-03 | avg. eps. 8.0243e-01
# iter. 0002 | Fval. 7.2048e-01 | BICval. 1.0490e+00 | Gcrit_x. 1.9350e-03 | avg. eps. 5.8413e-01
# iter. 0003 | Fval. 6.4208e-01 | BICval. 8.0565e-01 | Gcrit_x. 1.1054e-03 | avg. eps. 4.3692e-01
# iter. 0004 | Fval. 6.4201e-01 | BICval. 7.1084e-01 | Gcrit_x. 5.1777e-04 | avg. eps. 3.2920e-01
# iter. 0005 | Fval. 6.4177e-01 | BICval. 6.6928e-01 | Gcrit_x. 2.2667e-04 | avg. eps. 2.7267e-01
# iter. 0006 | Fval. 6.4175e-01 | BICval. 6.5224e-01 | Gcrit_x. 9.3087e-05 | avg. eps. 2.4449e-01
# iter. 0007 | Fval. 6.4175e-01 | BICval. 6.4559e-01 | Gcrit_x. 3.6321e-05 | avg. eps. 2.3158e-01
# iter. 0008 | Fval. 6.4175e-01 | BICval. 6.4311e-01 | Gcrit_x. 1.3576e-05 | avg. eps. 2.2734e-01
# iter. 0009 | Fval. 6.4175e-01 | BICval. 6.4221e-01 | Gcrit_x. 4.8864e-06 | avg. eps. 2.2743e-01
# iter. 0010 | Fval. 6.4175e-01 | BICval. 6.4190e-01 | Gcrit_x. 1.7002e-06 | avg. eps. 2.3125e-01
# iter. 0011 | Fval. 6.4175e-01 | BICval. 6.4180e-01 | Gcrit_x. 5.7376e-07 | avg. eps. 2.3727e-01
# iter. 0012 | Fval. 6.4175e-01 | BICval. 6.4176e-01 | Gcrit_x. 1.8835e-07 | avg. eps. 2.5009e-01
# iter. 0013 | Fval. 6.4175e-01 | BICval. 6.4175e-01 | Gcrit_x. 6.1093e-08 | avg. eps. 2.8030e-01
# iter. 0014 | Fval. 6.1538e-01 | BICval. 6.1681e-01 | Gcrit_x. 6.5538e-05 | avg. eps. 2.6121e-01
# iter. 0015 | Fval. 6.1360e-01 | BICval. 6.1430e-01 | Gcrit_x. 1.0015e-05 | avg. eps. 2.2987e-01
# iter. 0016 | Fval. 6.1129e-01 | BICval. 6.1185e-01 | Gcrit_x. 8.5922e-06 | avg. eps. 2.3062e-01
# iter. 0017 | Fval. 6.0867e-01 | BICval. 6.0925e-01 | Gcrit_x. 9.1650e-06 | avg. eps. 2.1430e-01
# iter. 0018 | Fval. 6.0859e-01 | BICval. 6.0876e-01 | Gcrit_x. 2.3941e-06 | avg. eps. 1.3927e-01
# iter. 0019 | Fval. 6.0836e-01 | BICval. 6.0845e-01 | Gcrit_x. 1.3338e-06 | avg. eps. 1.2685e-01
# iter. 0020 | Fval. 6.0832e-01 | BICval. 6.0835e-01 | Gcrit_x. 4.2043e-07 | avg. eps. 1.1312e-01
# iter. 0021 | Fval. 6.0821e-01 | BICval. 6.0823e-01 | Gcrit_x. 3.4590e-07 | avg. eps. 1.2138e-01
# iter. 0022 | Fval. 6.0810e-01 | BICval. 6.0811e-01 | Gcrit_x. 2.7844e-07 | avg. eps. 1.2622e-01
# iter. 0023 | Fval. 6.0810e-01 | BICval. 6.0810e-01 | Gcrit_x. 4.6583e-08 | avg. eps. 1.1392e-01
# iter. 0024 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 3.5975e-08 | avg. eps. 1.0560e-01
# iter. 0025 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 9.2208e-09 | avg. eps. 1.0032e-01
# iter. 0026 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 2.3450e-09 | avg. eps. 1.0377e-01
# iter. 0027 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 5.8877e-10 | avg. eps. 9.8306e-02
# iter. 0028 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 1.4624e-10 | avg. eps. 9.6195e-02
# iter. 0029 | Fval. 6.0809e-01 | BICval. 6.0809e-01 | Gcrit_x. 3.5730e-11 | avg. eps. 9.5461e-02
# => convergence to criticality ... polishing phase
# final::: Fval. 6.0809e-01 | BICval. 6.0809e-01
#
#  /!\ NEW BEST | F = 0.6080879302502961  /!\
#
# global
#
# -> computation with R_inf = 0.2 ; p-norm with p = inf
#
# ok for 10.382513661202186%
# ok for 20.76502732240437%
# ok for 31.147540983606557%
# ok for 41.53005464480874%
# ok for 51.91256830601093%
# ok for 62.295081967213115%
# ok for 72.6775956284153%
# ok for 83.06010928961749%
# ok for 93.44262295081968%
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 25 02:56:41 PM: Your problem has 23 variables, 51 constraints, and 0 parameters.
# (CVXPY) Jul 25 02:56:41 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 25 02:56:41 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 25 02:56:41 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:41 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 25 02:56:41 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jul 25 02:56:41 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 25 02:56:41 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jul 25 02:56:41 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jul 25 02:56:41 PM: Applying reduction GUROBI
# (CVXPY) Jul 25 02:56:41 PM: Finished problem compilation (took 3.896e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:41 PM: Invoking solver GUROBI  to obtain a solution.
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 891 rows, 412 columns and 1787 nonzeros
# Model fingerprint: 0x261932e4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-04, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 5e+01]
# Presolve removed 650 rows and 176 columns
# Presolve time: 0.01s
# Presolved: 241 rows, 236 columns, 517 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0      handle free variables                          0s
#      113    6.0808793e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 113 iterations and 0.01 seconds
# Optimal objective  6.080879302e-01
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 25 02:56:41 PM: Problem status: optimal
# (CVXPY) Jul 25 02:56:41 PM: Optimal value: 6.081e-01
# (CVXPY) Jul 25 02:56:41 PM: Compilation took 3.896e-01 seconds
# (CVXPY) Jul 25 02:56:41 PM: Solver (including time spent in interface) took 5.658e-02 seconds
#
# no improvement after globalization technique...
#
# => softmin (END)

# %%
endval_sm = np.array(endval_sm)
endval_single_run_sm = np.array(endval_single_run_sm)

# %%
np.mean((endval_single_run_sm-endval_sm)/np.abs(endval_single_run_sm))
# Out:
# 1.1027789725847926e-05

# %%
endval_single_run_sm-endval_sm
# Out:
# array([3.32760757e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00])

# %%
max((endval_single_run_sm-endval_sm)/np.abs(endval_single_run_sm))
# Out:
# 5.5138948629239634e-05

# %%
sum(locopt_sm)
# Out:
# 5
